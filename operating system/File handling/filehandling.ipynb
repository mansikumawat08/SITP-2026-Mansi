# %%
import os

# %%
file = open("poit.txt",'r')

# %%
file.read()
# Out:
# 'heloooooooo\nMy name is Mansi\n'

# %%
file.readline()
# Out:
# 'heloooooooo\n'

# %%
file.readlines()
# Out:
# ['heloooooooo\n', 'My name is Mansi\n']

# %%
file.close()

# %%
with open("poit.txt") as file:#works as for loop
    print(file.read())
# Out:
# heloooooooo
# My name is Mansi

# %%
file =open("poit1.txt",'w')#if file is not present it will create a new file
file.write("hello world")#write will overwrite the existing data
file.close()
file = open("poit.txt",'r')
print(file.read())
# Out:
# hello world

# %%
file = open("poit.txt",'a')#append will add data to the existing file
file.write("File handling is the process of creating, reading, writing, updating, and deleting files in a computer system using a program")
# Out:
# 125

# %%
open("poit.txt",'r').read()
# Out:
# 'hello worldFile handling is the process of creating, reading, writing, updating, and deleting files in a computer system using a program'

# %%
file = open('filehandling.txt','a')
file.write("File handling is the process of creating, reading, writing, updating, and deleting files in a computer system using a program.")
file.close()

# %%
file = open('filehandling1.txt','x')#x will create a new file if it is not present otherwise it will give an error.
file.write("File handling is the process of creating, reading, writing, updating, and deleting files in a computer system using a program.")
file.close()

# %% [markdown]
# EXCEPTION HANDLING
