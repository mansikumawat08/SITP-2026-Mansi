# %% [markdown]
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |

# %%
import os

# %%
os.getcwd()#geting current working diectory
# Out:
# 'c:\\Users\\HP\\OneDrive\\data science\\operating system'

# %%
path = r'c:\\Users\\HP\\OneDrive\\data science\\operating system'#dir using path
os.listdir(path)
# Out:
# ['basicos.ipynb']

# %%
os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\data science\\operating system'

# %%
os.listdir(r'c:\\Users\\HP\\OneDrive\\data science\\operating system')
# Out:
# ['basicos.ipynb', 'hello']

# %%
os.makedirs("student\\data\\reports")#used to create a dir ##student folder m data fr data m reports

# %%
os.listdir(os.getcwd())
# Out:
# ['basicos.ipynb', 'hello', 'student']

# %%
os.rmdir("hello")#removes the directory

# %%
os.listdir(os.getcwd())
# Out:
# ['basicos.ipynb', 'student']

# %%
os.rename("student","college")#used to rename(change)the name of directory

# %%
os.listdir(os.getcwd())
# Out:
# ['basicos.ipynb', 'college']

# %%
os.chdir(r"C:\Users\HP\OneDrive\data science\seeborn")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\OneDrive\\data science\\seeborn'

# %%
os.listdir(os.getcwd())
# Out:
# []

# %% [markdown]
# join paths

# %%
path = r"C:\Users\HP\Documents\Power BI Desktop\Custom Connectors"

path1 = r"C:\Users\HP\Documents"
path2 = r"Power BI Desktop\Custom Connectors"
complete_path =os.path.join(path1,path2)
print(complete_path)
print("final output:- ",os.listdir(complete_path))
# Out:
# C:\Users\HP\Documents\Power BI Desktop\Custom Connectors
# final output:-  ['order lines mansi (1).pbix']

# %%
os.path.isfile(r"C:\Users\HP\OneDrive\data science\operating system\basicos.ipynb")##to check a file
# Out:
# True

# %%
os.path.isdir('C:\\Users\\HP\\OneDrive\\data science\\seeborn')#to check a dir
# Out:
# True

# %%
os.path.exists(r"C:\Users\HP\OneDrive\data science\operating system\basicos.ipynb")
# Out:
# True

# %%
os.path.getsize(r"C:\Users\HP\OneDrive\data science\operating system\basicos.ipynb")
# Out:
# 8100
